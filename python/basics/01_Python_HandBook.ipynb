# %%
# Data maths operations
print("-" * 30)
print("Data maths operations")
print("Addition: 5 + 3 =", 5 + 3) 
print("Subtraction: 5 - 3 =", 5 - 3)
print("Multiplication: 5 * 3 =", 5 * 3)
print("Division: 5 / 3 =", 5 / 3)
print("Floor Division: 5 // 3 =", 5 // 3)
print("Modulus: 5 % 3 =", 5 % 3)
print("Exponentiation: 5 ** 3 =", 5 ** 3)
print("-" * 30)

print("Comment Types") 
print("# This is a single-line comment") # This is also a single-line comment
print(""" This is a multi-line comment      
that spans multiple lines
and is enclosed in triple quotes """)   # This is multi-line comment   
print("-" * 30)
# Out:
# ------------------------------
# Data maths operations
# Addition: 5 + 3 = 8
# Subtraction: 5 - 3 = 2
# Multiplication: 5 * 3 = 15
# Division: 5 / 3 = 1.6666666666666667
# Floor Division: 5 // 3 = 1
# Modulus: 5 % 3 = 2
# Exponentiation: 5 ** 3 = 125
# ------------------------------
# Comment Types
# # This is a single-line comment
#  This is a multi-line comment
# that spans multiple lines
# and is enclosed in triple quotes
# ------------------------------

# %%
# Data types
print("-" * 30)
print("Data types")
print("Integer:","42", type(42))
print("Float:","3.14", type(3.14))
print("String:","Hello, World!", type("Hello, World!"))
print("Boolean:","True", type(True))
print("List:","[1, 2, 3]", type([1, 2, 3]))
print("Tuple:","(1, 2, 3)", type((1, 2, 3)))
print("Dictionary:","{'key': 'value'}", type({'key': 'value'}))
print("Set:","{1, 2, 3}", type({1, 2, 3}))
print("-" * 30)
# Out:
# ------------------------------
# Data types
# Integer: 42 <class 'int'>
# Float: 3.14 <class 'float'>
# String: Hello, World! <class 'str'>
# Boolean: True <class 'bool'>
# List: [1, 2, 3] <class 'list'>
# Tuple: (1, 2, 3) <class 'tuple'>
# Dictionary: {'key': 'value'} <class 'dict'>
# Set: {1, 2, 3} <class 'set'>
# ------------------------------

# %%
# Built-in functions
print("-" * 30)
print("Built-in functions")
print("Length of 'Hello':", len("Hello"))
print("Maximum of [1, 2, 3]:", max([1, 2, 3]))
print("Minimum of [1, 2, 3]:", min([1, 2, 3]))
print("Sum of [1, 2, 3]:", sum([1, 2, 3]))
print("Type of 42:", type(42))
print("Range of 5:", list(range(5)))
print("-" * 30)

# Variable name rules
print("Variable name rules")
print("Valid variable names: my_variable, variable1, _private_var")
print("Invalid variable names: 1variable, my-variable, class")
print("-" * 30) 

# Declaring multiple variables
print("Declaring multiple variables")
a, b, c = 1, 2, 3
print("a =", a, "b =", b, "c =", c)
print("-" * 30)

# Data types and checking types
print("Data types and checking types")
x = 42
y = 3.14
z = "Hello"
print("x =", x, "type:", type(x))
print("y =", y, "type:", type(y))
print("z =", z, "type:", type(z))
print("-" * 30)
# Out:
# ------------------------------
# Built-in functions
# Length of 'Hello': 5
# Maximum of [1, 2, 3]: 3
# Minimum of [1, 2, 3]: 1
# Sum of [1, 2, 3]: 6
# Type of 42: <class 'int'>
# Range of 5: [0, 1, 2, 3, 4]
# ------------------------------
# Variable name rules
# Valid variable names: my_variable, variable1, _private_var
# Invalid variable names: 1variable, my-variable, class
# ------------------------------
# Declaring multiple variables
# a = 1 b = 2 c = 3
# ------------------------------
# Data types and checking types
# x = 42 type: <class 'int'>
# y = 3.14 type: <class 'float'>
# z = Hello type: <class 'str'>
# ------------------------------

# %%
# Assignment operators
print('-' * 30)
print("Assignment operators")
x = 10
print("Initial x =", x)
x += 5
print("After x += 5, x =", x)
x -= 3
print("After x -= 3, x =", x)
x *= 2
print("After x *= 2, x =", x)
x /= 4
print("After x /= 4, x =", x)
x //= 2
print("After x //= 2, x =", x)
x %= 3
print("After x %= 3, x =", x)
x **= 2
print("After x **= 2, x =", x)
print("-" * 30) 

# Comparison operators
print("Comparison operators")
a = 5
b = 3       
print("a =", a, "b =", b)
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
print("-" * 30)

# Logical operators
print("Logical operators")
x = True
y = False
print("x =", x, "y =", y)
print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)
print("not y:", not y)
print("-" * 30)
# Out:
# ------------------------------
# Assignment operators
# Initial x = 10
# After x += 5, x = 15
# After x -= 3, x = 12
# After x *= 2, x = 24
# After x /= 4, x = 6.0
# After x //= 2, x = 3.0
# After x %= 3, x = 0.0
# After x **= 2, x = 0.0
# ------------------------------
# Comparison operators
# a = 5 b = 3
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False
# ------------------------------
# Logical operators
# x = True y = False
# x and y: False
# x or y: True
# not x: False
# not y: True
# ------------------------------

# %%
# String operations
print("-" * 30) 
print("String operations")
s1 = "Hello"
s2 = "World"
print("s1 =", s1, "s2 =", s2)
print("Concatenation: s1 + s2 =", s1 + " " + s2)
print("Repetition: s1 * 3 =", s1 * 3)
print("Length of s1:", len(s1))
print("s1 in s2:", s1 in s2)
print("s1[0]:", s1[0])
print("s1[1:4]:", s1[1:4])
print("-" * 30) 

# Escape Sequences
print("Escape sequences")
print("Newline: Hello\nWorld")
print("Tab: Hello\tWorld")
print("Backslash: Hello\\World")
print("Single quote: Hello\'s World")
print("Double quote: Hello\"s World")
print("-" * 30)

# String Formatting
print("String formatting")
name = "Alice"
age = 30
print("Using str.format(): My name is {} and I am {} years old.".format(name, age))
print(f"Using f-strings: My name is {name} and I am {age} years old.")
print("-" * 30)
# Out:
# ------------------------------
# String operations
# s1 = Hello s2 = World
# Concatenation: s1 + s2 = Hello World
# Repetition: s1 * 3 = HelloHelloHello
# Length of s1: 5
# s1 in s2: False
# s1[0]: H
# s1[1:4]: ell
# ------------------------------
# Escape sequences
# Newline: Hello
# World
# Tab: Hello	World
# Backslash: Hello\World
# Single quote: Hello's World
# Double quote: Hello"s World
# ------------------------------
# String formatting
# Using str.format(): My name is Alice and I am 30 years old.
# Using f-strings: My name is Alice and I am 30 years old.
# ------------------------------

# %%
# Accessing characters in a string  
print("Accessing characters in a string")
s = "Hello, World!"
print("s =", s)
print("s[0]:", s[0])
print("s[7]:", s[7])
print("s[-1]:", s[-1])
print("s[0:5]:", s[0:5])
print("s[7:]:", s[7:])
print("s[:5]:", s[:5])
print("s[::2]:", s[::2])
print("-" * 30)

# String Methods
print("String methods")
s = "hello, world!"
print("s =", s)
print("s.upper():", s.upper()) # Converts all characters in the string to uppercase.
print("s.lower():", s.lower()) # Converts all characters in the string to lowercase.
print("s.title():", s.title()) # Converts the first character of each word to uppercase.
print("s.strip():", s.strip()) # Removes leading and trailing whitespace.
print("s.replace('o', '0'):", s.replace('o', '0')) # Replaces all occurrences of a substring with another substring.
print("s.split(', '):", s.split(', ')) # Splits the string into a list of substrings based on a delimiter.
print("s.find('world'):", s.find('world')) # Returns the lowest index of the substring if it is found in the string, otherwise returns -1.
print("s.startswith('hello'):", s.startswith('hello')) # Returns True if the string starts with the specified prefix, otherwise returns False.
print("s.endswith('!'):", s.endswith('!')) # Returns True if the string ends with the specified suffix, otherwise returns False.
print("-" * 30)
# Out:
# Accessing characters in a string
# s = Hello, World!
# s[0]: H
# s[7]: W
# s[-1]: !
# s[0:5]: Hello
# s[7:]: World!
# s[:5]: Hello
# s[::2]: Hlo ol!
# ------------------------------
# String methods
# s = hello, world!
# s.upper(): HELLO, WORLD!
# s.lower(): hello, world!
# s.title(): Hello, World!
# s.strip(): hello, world!
# s.replace('o', '0'): hell0, w0rld!
# s.split(', '): ['hello', 'world!']
# s.find('world'): 7
# s.startswith('hello'): True
# s.endswith('!'): True
# ------------------------------

# %%
# Lists 
print("Lists")
my_list = [1, 2, 3, 4, 5]
print("my_list =", my_list)
print("Length of my_list:", len(my_list))
print("Accessing my_list[0]:", my_list[0])
print("Accessing my_list[1:4]:", my_list[1:4])
print("Accessing my_list[-1]:", my_list[-1])
print("-" * 30)
print("Unpacking lists")
a, b, c, d, e = my_list
print("first element a =", a)
print("second element b =", b)
print("third element c =", c)
print("fourth element d =", d)
print("fifth element e =", e)
print("-" * 30)
# Out:
# Lists
# my_list = [1, 2, 3, 4, 5]
# Length of my_list: 5
# Accessing my_list[0]: 1
# Accessing my_list[1:4]: [2, 3, 4]
# Accessing my_list[-1]: 5
# ------------------------------
# Unpacking lists
# first element a = 1
# second element b = 2
# third element c = 3
# fourth element d = 4
# fifth element e = 5
# ------------------------------

# %%
print("List methods")
my_list = [1, 2, 3, 4, 5]
print("my_list =", my_list)
print("my_list.append(6):", my_list.append(6)) # Adds an item to the end of the list.
print("my_list after append:", my_list)
print("my_list.insert(0, 0):", my_list.insert(0, 0)) # Inserts an item at a specified position.
print("my_list after insert:", my_list)
print("my_list.remove(3):", my_list.remove(3)) # Removes the first occurrence of a value.
print("my_list after remove:", my_list)
print("my_list.pop():", my_list.pop()) # Removes and returns the last item in the list.
print("my_list after pop:", my_list)
print("my_list.pop(0):", my_list.pop(0)) # Removes and returns the item at a specified position.
print("my_list after pop(0):", my_list)
print("my_list.sort():", my_list.sort()) # Sorts the items of the list in place.
print("my_list after sort:", my_list)
print("my_list.reverse():", my_list.reverse()) # Reverses the elements of the list in place.
print("my_list after reverse:", my_list)
print("my_list.count(2):", my_list.count(2)) # Returns the number of occurrences of a value.
print("my_list.index(4):", my_list.index(4)) # Returns the index of the first occurrence of a value.
my_list_copy = my_list.copy() # Returns a shallow copy of the list.
print("my_list_copy:", my_list_copy)    
my_list.clear() # Removes all items from the list.
print("my_list after clear:", my_list)  
my_list3= my_list + my_list_copy
print("my_list3 (after concatenation):", my_list3)
print("my_list3.count(2):", my_list3.count(2)) # Returns the number of occurrences of a value in my_list3
print("-" * 30)
# Out:
# List methods
# my_list = [1, 2, 3, 4, 5]
# my_list.append(6): None
# my_list after append: [1, 2, 3, 4, 5, 6]
# my_list.insert(0, 0): None
# my_list after insert: [0, 1, 2, 3, 4, 5, 6]
# my_list.remove(3): None
# my_list after remove: [0, 1, 2, 4, 5, 6]
# my_list.pop(): 6
# my_list after pop: [0, 1, 2, 4, 5]
# my_list.pop(0): 0
# my_list after pop(0): [1, 2, 4, 5]
# my_list.sort(): None
# my_list after sort: [1, 2, 4, 5]
# my_list.reverse(): None
# my_list after reverse: [5, 4, 2, 1]
# my_list.count(2): 1
# my_list.index(4): 1
# my_list_copy: [5, 4, 2, 1]
# my_list after clear: []
# my_list3 (after concatenation): [5, 4, 2, 1]
# my_list3.count(2): 1
# ------------------------------

# %%
# Tuples
print("Tuples")
my_tuple = (1, 2, 3, 4, 5)
print("my_tuple =", my_tuple)
print("Length of my_tuple:", len(my_tuple))
print("Accessing my_tuple[0]:", my_tuple[0])
print("Accessing my_tuple[1:4]:", my_tuple[1:4])
print("Accessing my_tuple[-1]:", my_tuple[-1])
del my_tuple # Tuples are immutable, so we cannot modify them, but we can delete them.
print("-" * 30)
# Out:
# Tuples
# my_tuple = (1, 2, 3, 4, 5)
# Length of my_tuple: 5
# Accessing my_tuple[0]: 1
# Accessing my_tuple[1:4]: (2, 3, 4)
# Accessing my_tuple[-1]: 5
# ------------------------------

# %%
# Sets
print("Sets")
my_set = {1, 2, 3, 4, 5}
print("my_set =", my_set)
print("Length of my_set:", len(my_set))
print("Accessing my_set[0]:", "Sets do not support indexing") # Sets do not support indexing, so we cannot access elements by index.
print("Adding an element to my_set:", my_set.add(6)) # Adds an element to the set.
print("my_set after adding 6:", my_set)
print("Removing an element from my_set:", my_set.remove(3)) # Removes an element from the set. Raises a KeyError if the element is not found.
print("my_set after removing 3:", my_set)
print("my_set.discard(10):", my_set.discard(10)) # Removes an element from the set if it is a member. If the element is not a member, does nothing.
print("my_set after discard(10):", my_set)
print("my_set.pop():", my_set.pop()) # Removes and returns an arbitrary element from the set. Raises a KeyError if the set is empty.
print("my_set after pop():", my_set)
print("my_set.clear():", my_set.clear()) # Removes all elements from the set.
print("my_set after clear():", my_set)
del my_set # We can delete the set itself.
print("-" * 30)
# Set convertions
print("Set conversions")
my_list = [1, 2, 3, 4, 5]
my_tuple = (1, 2, 3, 4, 5)
my_set = {1, 2, 3, 4, 5}
print("my_list to set:", set(my_list)) # Converts a list to a set.
print("my_tuple to set:", set(my_tuple)) # Converts a tuple to a set.
print("my_set to list:", list(my_set)) # Converts a set to a list.
print("my_set to tuple:", tuple(my_set)) # Converts a set to a tuple.
print("-" * 30)
# Out:
# Sets
# my_set = {1, 2, 3, 4, 5}
# Length of my_set: 5
# Accessing my_set[0]: Sets do not support indexing
# Adding an element to my_set: None
# my_set after adding 6: {1, 2, 3, 4, 5, 6}
# Removing an element from my_set: None
# my_set after removing 3: {1, 2, 4, 5, 6}
# my_set.discard(10): None
# my_set after discard(10): {1, 2, 4, 5, 6}
# my_set.pop(): 1
# my_set after pop(): {2, 4, 5, 6}
# my_set.clear(): None
# my_set after clear(): set()
# ------------------------------
# Set conversions
# my_list to set: {1, 2, 3, 4, 5}
# my_tuple to set: {1, 2, 3, 4, 5}
# my_set to list: [1, 2, 3, 4, 5]
# my_set to tuple: (1, 2, 3, 4, 5)
# ------------------------------

# %%
# Dictionaries
print("Dictionaries")
my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
print("my_dict =", my_dict)
print("Length of my_dict:", len(my_dict))
print("Accessing my_dict['name']:", my_dict['name'])
print("Accessing my_dict.get('age'):", my_dict.get('age')) # Returns the value for the specified key if the key is in the dictionary, otherwise returns None.
print("Accessing my_dict.get('country', 'USA'):", my_dict.get('country', 'USA')) # Returns the value for the specified key if the key is in the dictionary, otherwise returns the default value 'USA'.
print("my_dict.keys():", my_dict.keys()) # Returns a view object that displays a list of all the keys in the dictionary.
print("my_dict.values():", my_dict.values()) # Returns a view object that displays a list of all the values in the dictionary.
print("my_dict.items():", my_dict.items()) # Returns a view object that displays a list of the dictionary's key-value pairs as tuples.
print("Adding a new key-value pair to my_dict:", my_dict.update({'country': 'USA'})) # Adds a key-value pair to the dictionary.
print("my_dict after adding country:", my_dict)
print("Removing a key-value pair from my_dict:", my_dict.pop('age')) # Removes a key-value pair from the dictionary and returns the value. Raises a KeyError if the key is not found.
print("my_dict after removing age:", my_dict)
print("my_dict.pop('age', 'Not Found'):", my_dict.pop('age', 'Not Found')) # Removes a key-value pair from the dictionary and returns the value. If the key is not found, returns the default value 'Not Found'.
print("my_dict after popping age again:", my_dict)
my_dict_2 = my_dict.copy() # Returns a shallow copy of the dictionary.
print("my_dict_copy:", my_dict_2)
print("my_dict.clear():", my_dict.clear()) # Removes all key-value pairs from the dictionary.
print("my_dict after clear():", my_dict)
del my_dict # We can delete the dictionary itself.
print("-" * 30)
# Out:
# Dictionaries
# my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
# Length of my_dict: 3
# Accessing my_dict['name']: Alice
# Accessing my_dict.get('age'): 30
# Accessing my_dict.get('country', 'USA'): USA
# my_dict.keys(): dict_keys(['name', 'age', 'city'])
# my_dict.values(): dict_values(['Alice', 30, 'New York'])
# my_dict.items(): dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])
# Adding a new key-value pair to my_dict: None
# my_dict after adding country: {'name': 'Alice', 'age': 30, 'city': 'New York', 'country': 'USA'}
# Removing a key-value pair from my_dict: 30
# my_dict after removing age: {'name': 'Alice', 'city': 'New York', 'country': 'USA'}
# my_dict.pop('age', 'Not Found'): Not Found
# my_dict after popping age again: {'name': 'Alice', 'city': 'New York', 'country': 'USA'}
# my_dict_copy: {'name': 'Alice', 'city': 'New York', 'country': 'USA'}
# my_dict.clear(): None
# my_dict after clear(): {}
# ------------------------------

# %%
# Conditionals
print("Conditionals")
x = 10
if x > 5:
    print("x is greater than 5")
elif x == 5:
    print("x is equal to 5")
else:
    print("x is less than 5")   
print("-" * 30)

# Short-hand if-else (ternary operator)
print("Short-hand if-else (ternary operator)")
y = 20
result = "y is greater than 15" if y > 15 else "y is not greater than 15"
print(result)
print("-" * 30) 

# Nested conditionals
print("Nested conditionals")
z = 7
if z > 5:
    if z < 10:
        print("z is between 5 and 10")
    else:
        print("z is greater than or equal to 10")
else:
    print("z is less than or equal to 5")
print("-" * 30)

# Condition with logical operators
print("Condition with logical operators")
a = 5
b = 10
if a > 0 and b > 0:
    print("Both a and b are positive")
if a > 0 or b > 0:
    print("At least one of a or b is positive")
if not (a < 0):
    print("a is not negative")
print("-" * 30)
# Out:
# Conditionals
# x is greater than 5
# ------------------------------
# Short-hand if-else (ternary operator)
# y is greater than 15
# ------------------------------
# Nested conditionals
# z is between 5 and 10
# ------------------------------
# Condition with logical operators
# Both a and b are positive
# At least one of a or b is positive
# a is not negative
# ------------------------------

# %%
# Loops
print("Loops")
print("-" * 30)
# While loop
print("While loop")
i = 0
while i < 5:
    print("i =", i)
    i += 1
print("-" * 30) 
# break and continue
print("break and continue")
j = 0
while j < 10:
    if j == 3:
        print("Skipping j =", j)
        j += 1
        continue
    if j == 7:
        print("Breaking at j =", j)
        break
    print("j =", j)
    j += 1
print("-" * 30)
# Out:
# Loops
# ------------------------------
# While loop
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4
# ------------------------------
# break and continue
# j = 0
# j = 1
# j = 2
# Skipping j = 3
# j = 4
# j = 5
# j = 6
# Breaking at j = 7
# ------------------------------

# %%
# For loop
print("For loop")
for k in range(5):
    print("k =", k)
print("-" * 30)

# For loop with else
print("For loop with else")
for m in range(5):
    print("m =", m)
else:
    print("Loop completed without break")
print("-" * 30)

# Nested for loops
print("Nested for loops")
for i in range(3):
    for j in range(2):
        print(f"i = {i}, j = {j}")
print("-" * 30)
# Out:
# For loop
# k = 0
# k = 1
# k = 2
# k = 3
# k = 4
# ------------------------------
# For loop with else
# m = 0
# m = 1
# m = 2
# m = 3
# m = 4
# Loop completed without break
# ------------------------------
# Nested for loops
# i = 0, j = 0
# i = 0, j = 1
# i = 1, j = 0
# i = 1, j = 1
# i = 2, j = 0
# i = 2, j = 1
# ------------------------------

# %%
# break and continue in for loop
print("break and continue in for loop")
for m in range(10):
    if m == 4:
        print("Skipping m =", m)
        continue
    if m == 8:
        print("Breaking at m =", m)
        break
    print("m =", m)
print("-" * 30)

# Range with start, stop, and step
print("Range with start, stop, and step")
for n in range(1, 10, 2):
    print("n =", n)
print("-" * 30)

# Pass statement
print("Pass statement")
for p in range(5):
    if p == 2:
        pass  # Placeholder for future code
    print("p =", p)
print("-" * 30)
# Out:
# break and continue in for loop
# m = 0
# m = 1
# m = 2
# m = 3
# Skipping m = 4
# m = 5
# m = 6
# m = 7
# Breaking at m = 8
# ------------------------------
# Range with start, stop, and step
# n = 1
# n = 3
# n = 5
# n = 7
# n = 9
# ------------------------------
# Pass statement
# p = 0
# p = 1
# p = 2
# p = 3
# p = 4
# ------------------------------

# %%
# Defining a function

def greet(name):
    return f"Hello, {name}!"
# Calling the function
print(greet("Alice"))
print("-" * 30)

# Without parameters
def say_hello():
    return "Hello!"
print(say_hello())
print("-" * 30)

# Returning a value
def add(a, b):
    return a + b
print("add(3, 5):", add(3, 5))
print("-" * 30)

# Returning lists
def get_even_numbers(n):
    return [i for i in range(n) if i % 2 == 0]
print("get_even_numbers(10):", get_even_numbers(10))
print("-" * 30)

# Default parameters
def greet(name="World"):
    return f"Hello, {name}!"
print(greet())  # Uses default parameter
print(greet("Alice"))  # Overrides default parameter
print("-" * 30)

# Arbitrary number of arguments
def sum_all(*args):
    return sum(args)
print("sum_all(1, 2, 3):", sum_all(1, 2, 3))
print("sum_all(4, 5):", sum_all(4, 5))
print("-" * 30)
# Out:
# Hello, Alice!
# ------------------------------
# Hello!
# ------------------------------
# add(3, 5): 8
# ------------------------------
# get_even_numbers(10): [0, 2, 4, 6, 8]
# ------------------------------
# Hello, World!
# Hello, Alice!
# ------------------------------
# sum_all(1, 2, 3): 6
# sum_all(4, 5): 9
# ------------------------------

# %%
# Modules 
import math
print("Math module:")
print("Square root of 16:", math.sqrt(16))
print("Value of pi:", math.pi)
print("2 raised to the power of 3:", math.pow(2, 3))
print("Logarithm of 1000 to base 10:", math.log10(1000))
print("Factorial of 5:", math.factorial(5))
print("Greatest common divisor of 48 and 18:", math.gcd(48, 18))
print("-" * 30)

# Built-in modules
import random
print("Random module:")
print("Random integer between 1 and 10:", random.randint(1, 10))
print("Random choice from a list:", random.choice(['apple', 'banana', 'cherry']))
print("-" * 30)
import os
print("OS module:")
print("Current working directory:", os.getcwd())
print("-" * 30) 
import datetime
print("Datetime module:")
print("Current date and time:", datetime.datetime.now())
print("-" * 30)
import sys
print("Sys module:")
print("Python version:", sys.version)
print("-" * 30)
import json
print("JSON module:")
data = {"name": "Alice", "age": 30, "city": "New York"}
json_data = json.dumps(data)  # Convert Python dictionary to JSON string
print("JSON data:", json_data)
print("-" * 30)
from statistics import *
print("Statistics module:")
numbers = [1, 2, 3, 4, 5]
print("Mean:", mean(numbers))
print("Median:", median(numbers))
print("Mode:", mode(numbers))
print("-" * 30)
# Out:
# Math module:
# Square root of 16: 4.0
# Value of pi: 3.141592653589793
# 2 raised to the power of 3: 8.0
# Logarithm of 1000 to base 10: 3.0
# Factorial of 5: 120
# Greatest common divisor of 48 and 18: 6
# ------------------------------
# Random module:
# Random integer between 1 and 10: 6
# Random choice from a list: cherry
# ------------------------------
# OS module:
# Current working directory: /Users/timu/CodeS/cs-fundamentals/python/basics
# ------------------------------
# Datetime module:
# Current date and time: 2026-03-29 15:47:00.628636
# ------------------------------
# Sys module:
# Python version: 3.12.2 (main, Feb 10 2026, 06:32:17) [Clang 17.0.0 (clang-1700.6.3.2)]
# ------------------------------
# JSON module:
# JSON data: {"name": "Alice", "age": 30, "city": "New York"}
# ------------------------------
# Statistics module:
# Mean: 3
# Median: 3
# Mode: 1
# ------------------------------

# %%
# List comprehensions
squares = [x**2 for x in range(10)]
print("Squares from 0 to 9:", squares)
print("-" * 30)

# if-else in list comprehensions
even_odd = ["Even" if x % 2 == 0 else "Odd" for x in range(10)]
print("Even or Odd from 0 to 9:", even_odd)
print("-" * 30)

# Lambda functions
add = lambda x, y: x + y
print("Lambda function add(3, 5):", add(3, 5))
print("-" * 30)

# Lambda fuctions inside anhother function
def make_multiplier(n):
    return lambda x: x * n
double = make_multiplier(2)
print("Double of 5:", double(5))
print("-" * 30)
# Out:
# Squares from 0 to 9: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ------------------------------
# Even or Odd from 0 to 9: ['Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd']
# ------------------------------
# Lambda function add(3, 5): 8
# ------------------------------
# Double of 5: 10
# ------------------------------

# %%
# Higher-order functions

def sum_list(func, lst):    
    return func(lst)
numbers = [1, 2, 3, 4, 5]

print("Sum of numbers using sum_list and sum function:", sum_list(sum, numbers))    
print("-" * 30)

# Map, filter, and reduce

from functools import reduce
numbers = [1, 2, 3, 4, 5]

squared = list(map(lambda x: x**2, numbers)) # Map applies a function to all items in the input list.
print("Squared numbers:", squared)

even_numbers = list(filter(lambda x: x % 2 == 0, numbers)) # Filter creates a list of elements for which a function returns true.
print("Even numbers:", even_numbers)

product = reduce(lambda x, y: x * y, numbers) # Reduce applies a rolling computation to sequential pairs of values in a list.
print("Product of numbers:", product)
print("-" * 30)
# Out:
# Sum of numbers using sum_list and sum function: 15
# ------------------------------
# Squared numbers: [1, 4, 9, 16, 25]
# Even numbers: [2, 4]
# Product of numbers: 120
# ------------------------------

# %%
# Python Error Types
print("SyntaxError: This error occurs when the parser encounters a syntax error in the code.")
print("NameError: This error occurs when a local or global name is not found.")
print("TypeError: This error occurs when an operation or function is applied to an object of inappropriate type.")
print("ValueError: This error occurs when a function receives an argument of the correct type but an inappropriate value.")
print("IndexError: This error occurs when a sequence subscript is out of range.")
print("KeyError: This error occurs when a dictionary key is not found.")
print("AttributeError: This error occurs when an attribute reference or assignment fails.")
print("ZeroDivisionError: This error occurs when the second argument of a division or modulo operation is zero.")
print("ImportError: This error occurs when an import statement fails to find the module definition.")
print("FileNotFoundError: This error occurs when a file or directory is requested but cannot be found.")
print("TypeError: This error occurs when an operation or function is applied to an object of inappropriate type.")
print("-" * 30)

# Exception handling
print("Exception handling")
try:    result = 10 / 0
except ZeroDivisionError as e:
    print("Caught an exception:", e)
finally:    print("This block will always execute")
print("-" * 30)
# Out:
# SyntaxError: This error occurs when the parser encounters a syntax error in the code.
# NameError: This error occurs when a local or global name is not found.
# TypeError: This error occurs when an operation or function is applied to an object of inappropriate type.
# ValueError: This error occurs when a function receives an argument of the correct type but an inappropriate value.
# IndexError: This error occurs when a sequence subscript is out of range.
# KeyError: This error occurs when a dictionary key is not found.
# AttributeError: This error occurs when an attribute reference or assignment fails.
# ZeroDivisionError: This error occurs when the second argument of a division or modulo operation is zero.
# ImportError: This error occurs when an import statement fails to find the module definition.
# FileNotFoundError: This error occurs when a file or directory is requested but cannot be found.
# ...

# %%
# Regular expressions
import re
print("Regular expressions")
text = "The rain in Spain stays mainly in the plain."
print("Text:", text)
pattern = r'\b\w+ain\b' # Matches words that end with 'ain'
matches = re.findall(pattern, text) # Finds all occurrences of the pattern in the text.
print("Words that end with 'ain':", matches)
print("-" * 30) 

# Searching and replacing with regular expressions
new_text = re.sub(r'\b\w+ain\b', 'XXX', text) # Replaces all occurrences of the pattern with 'XXX'.
print("Text after replacement:", new_text)
print("-" * 30)
# Out:
# Regular expressions
# Text: The rain in Spain stays mainly in the plain.
# Words that end with 'ain': ['rain', 'Spain', 'plain']
# ------------------------------
# Text after replacement: The XXX in XXX stays mainly in the XXX.
# ------------------------------

# %%
# File handling
print("File handling")
try:    with open('example.txt', 'w') as f: # Opens a file for writing. If the file does not exist, it will be created.
        f.write("Hello, World!\nThis is a file handling example.")
    with open('example.txt', 'r') as f: # Opens a file for reading.
        content = f.read() # Reads the entire content of the file.
        print("File content:\n", content)
except FileNotFoundError as e:
    print("Caught an exception:", e)
print("-" * 30) 

# Open files for reading, writing, and appending
try:    with open('example.txt', 'w') as f: # Opens a file for writing. If the file does not exist, it will be created.
        f.write("This is a new line.\n")
    with open('example.txt', 'a') as f: # Opens a file for appending. If the file does not exist, it will be created.
        f.write("This line is appended.\n")
    with open('example.txt', 'r') as f: # Opens a file for reading.
        content = f.read() # Reads the entire content of the file.
        print("File content after writing and appending:\n", content)
except FileNotFoundError as e:
    print("Caught an exception:", e)
print("-" * 30) 

# File types and modes
print("File types and modes")   
print("Text files: Opened in 'r', 'w', or 'a' mode. Data is read/written as strings.")
print("Binary files: Opened in 'rb', 'wb', or 'ab' mode. Data is read/written as bytes.")
print("-" * 30)

# Deleting a file
import os
try:    os.remove('example.txt') # Deletes the file named 'example.txt'.
    print("File 'example.txt' deleted successfully.")
except FileNotFoundError as e:
    print("Caught an exception:", e)
print("-" * 30)

# Saveing JSON data to a file
try:    with open('data.json', 'w') as f: # Opens a file for writing. If the file does not exist, it will be created.
        json.dump(data, f) # Writes a Python object to a file as JSON.
    with open('data.json', 'r') as f: # Opens a file for reading.
        loaded_data = json.load(f) # Reads a JSON object from a file and converts it to a Python object.
        print("Loaded data from JSON file:", loaded_data)
except FileNotFoundError as e:
    print("Caught an exception:", e)
print("-" * 30)

# Creating Json files
import json
data = {"name": "Alice", "age": 30, "city": "New York"}
json_data = json.dumps(data)  # Convert Python dictionary to JSON string
print("JSON data:", json_data)
print("-" * 30)
# Out:
#   File <string>:5
#     with open('example.txt', 'r') as f: # Opens a file for reading.
#                                                                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Python Pip   
print("Python Pip")
print("Pip is a package manager for Python that allows you to install and manage additional libraries and dependencies that are not included in the standard library.")
print("To install a package using pip, you can use the command: pip install package_name")
print("To upgrade a package using pip, you can use the command: pip install --upgrade package_name")
print("To uninstall a package using pip, you can use the command: pip uninstall package_name")
print("-" * 30)

# installing a package using pip
print("Installing a package using pip")
print("To install a package, run the command: pip install package_name")
print("For example, to install the requests library, you would run: pip install requests")
print("-" * 30)

# Checking version
print("Checking version of a package")
print("To check the version of an installed package, you can use the command: pip show package_name")
print("For example, to check the version of the requests library, you would run: pip show requests")
print("-" * 30) 

# Pip modules
print("Pip modules")
print("Some popular pip modules include:")
print("1. requests: A library for making HTTP requests.")
print("2. numpy: A library for numerical computing.")
print("3. pandas: A library for data manipulation and analysis.")
print("4. matplotlib: A library for creating static, animated, and interactive visualizations.")
print("5. scikit-learn: A library for machine learning.")
print("-" * 30) 

# Uninstalling a package using pip
print("Uninstalling a package using pip")
print("To uninstall a package, run the command: pip uninstall package_name")
print("For example, to uninstall the requests library, you would run: pip uninstall requests")
print("-" * 30)
# Out:
# Python Pip
# Pip is a package manager for Python that allows you to install and manage additional libraries and dependencies that are not included in the standard library.
# To install a package using pip, you can use the command: pip install package_name
# To upgrade a package using pip, you can use the command: pip install --upgrade package_name
# To uninstall a package using pip, you can use the command: pip uninstall package_name
# ------------------------------
# Installing a package using pip
# To install a package, run the command: pip install package_name
# For example, to install the requests library, you would run: pip install requests
# ------------------------------
# Checking version of a package
# To check the version of an installed package, you can use the command: pip show package_name
# For example, to check the version of the requests library, you would run: pip show requests
# ------------------------------
# Pip modules
# Some popular pip modules include:
# ...

# %%
# Class and Object Oriented Programming
print("Class and Object Oriented Programming")
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        return f"Hello, my name is {self.name} and I am {self.age} years old."
person1 = Person("Alice", 30)
print(person1.greet())
print("-" * 30)

# Class constructors
print("Class constructors")
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    def get_info(self):
        return f"{self.year} {self.make} {self.model}"
car1 = Car("Toyota", "Camry", 2020)
print(car1.get_info())
print("-" * 30)

# Object methods
print("Object methods")
class Circle:
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
    def circumference(self):
        return 2 * math.pi * self.radius
circle1 = Circle(5)
print("Area of the circle:", circle1.area())
print("Circumference of the circle:", circle1.circumference())
print("-" * 30)

# Object default Methods
print("Object default methods")
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
point1 = Point(2, 3)
print("Point coordinates:", (point1.x, point1.y))
print("String representation of point1:", str(point1)) # Default string representation of the object
print("-" * 30) 

# Inheritance
print("Inheritance")
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        return "Animal sound"
class Dog(Animal):
    def speak(self):
        return "Woof!"
class Cat(Animal):
    def speak(self):
        return "Meow!"
dog1 = Dog("Buddy")
cat1 = Cat("Whiskers")
print(dog1.name, "says:", dog1.speak())
print(cat1.name, "says:", cat1.speak())
print("-" * 30)
# Out:
# Class and Object Oriented Programming
# Hello, my name is Alice and I am 30 years old.
# ------------------------------
# Class constructors
# 2020 Toyota Camry
# ------------------------------
# Object methods
# Area of the circle: 78.53981633974483
# Circumference of the circle: 31.41592653589793
# ------------------------------
# Object default methods
# Point coordinates: (2, 3)
# String representation of point1: <__main__.Point object at 0x10c3cf860>
# ------------------------------
# Inheritance
# Buddy says: Woof!
# Whiskers says: Meow!
# ------------------------------

# %%
# Python web scraping
print("Python web scraping")
import requests
from bs4 import BeautifulSoup
url = "https://www.example.com"
response = requests.get(url) # Sends a GET request to the specified URL and returns a response object.
if response.status_code == 200: # Checks if the request was successful (status code 200).
    soup = BeautifulSoup(response.content, 'html.parser') # Parses the HTML content of the response using BeautifulSoup.
    title = soup.title.string # Extracts the title of the webpage.
    print("Title of the webpage:", title)
else:    print("Failed to retrieve the webpage. Status code:", response.status_code)
print("-" * 30)
# Out:
# Python web scraping
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 3
#       1 # Python web scraping
#       2 print("Python web scraping")
# ----> 3 import requests
#       4 from bs4 import BeautifulSoup
#       5 url = "https://www.example.com"
#
# ModuleNotFoundError: No module named 'requests'

# %%
# Setting up a virtual environment
print("Setting up a virtual environment")
print("To create a virtual environment, run the command: python -m venv env_name")
print("To activate the virtual environment:")
print("On Windows: env_name\\Scripts\\activate")
print("On macOS/Linux: source env_name/bin/activate")
print("python -m venv env_name: This command creates a virtual environment named 'env_name' in the current directory.")
print("source env_name/bin/activate: This command activates the virtual environment on macOS/Linux. After activation, any packages installed using pip will be isolated to this environment.") 
print("To deactivate the virtual environment, run the command: deactivate")
print("-" * 30)
# Out:
# Setting up a virtual environment
# To create a virtual environment, run the command: python -m venv env_name
# To activate the virtual environment:
# On Windows: env_name\Scripts\activate
# On macOS/Linux: source env_name/bin/activate
# python -m venv env_name: This command creates a virtual environment named 'env_name' in the current directory.
# source env_name/bin/activate: This command activates the virtual environment on macOS/Linux. After activation, any packages installed using pip will be isolated to this environment.
# To deactivate the virtual environment, run the command: deactivate
# ------------------------------
